# %% [markdown]
# # Import The Packages Needed
#
#
# ---

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from xgboost import XGBRegressor
import random
from sklearn import ensemble
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import mean_squared_error as MSE
from sklearn.inspection import permutation_importance
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans

# %% [markdown]
# # Read And Examine the Files
#
# *   Check data types
# *   Check Outliers in Numeric Data
# *   Check Unique Values

# %%
#The training files are saved as zip files. I am decompressing the files first then reading them into dataframes. 

df = pd.read_csv('AB_NYC_2019.csv')
#inspect the training_features dataframe
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df.reviews_per_month.value_counts()
# Out:
# 0.02     919
# 0.05     893
# 1.00     893
# 0.03     804
# 0.16     667
#         ...
# 9.53       1
# 9.74       1
# 6.06       1
# 8.25       1
# 10.54      1
# Name: reviews_per_month, Length: 937, dtype: int64

# %%
#checking if there are any null values in the dataframe
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#take out the rows that are empty in these columns
df.fillna({'reviews_per_month':0}, inplace=True)
df.fillna({'host_name':"NoName"}, inplace=True)
df.fillna({'last_review':"NotReviewed"}, inplace=True)
df = df[df['name'].notna()]

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
#describe the data
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.887900e+04  4.887900e+04  48879.000000  48879.000000  48879.000000
# mean   1.902062e+07  6.763013e+07     40.728945    -73.952168    152.722355
# std    1.098282e+07  7.862070e+07      0.054529      0.046160    240.186804
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.474248e+06  7.816856e+06     40.690090    -73.983070     69.000000
# 50%    1.968643e+07  3.079133e+07     40.723080    -73.955680    106.000000
# 75%    2.915334e+07  1.074344e+08     40.763110    -73.936280    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48879.000000       48879.000000       48879.000000
# mean         7.011027          23.281205           1.091248
# std         20.016000          44.556149           1.597433
# min          1.000000           0.000000           0.000000
# 25%          1.000000           1.000000           0.040000
# 50%          3.000000           5.000000           0.370000
# 75%          5.000000          24.000000           1.580000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48879.000000      48879.000000
# mean                         7.145891        112.788989
# std                         32.957738        131.613322
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %%
#look for the sum of all the values that are empty in the dataframe
df.shape
# Out:
# (48879, 16)

# %%
#handle longitude and latitude data

# %%
plt.figure(figsize = (10,8))
sns.scatterplot(x=df['longitude'], hue = df['availability_365'], y=df['latitude'],c=df['price'],cmap=plt.get_cmap('jet'), palette = 'inferno',alpha=0.4)
plt.show()

# %%
K_clusters = range(1,10)

kmeans = [KMeans(n_clusters=i) for i in K_clusters]

Y_axis = df[['latitude']]
X_axis = df[['longitude']]

score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]

plt.plot(K_clusters, score)
plt.xlabel("Number of Clusters")
plt.ylabel('Score')

plt.title("Elbow Curve")
plt.show()

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
location = df[['id','longitude','latitude']]

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++')
kmeans.fit(location)

df['location_cluster'] = kmeans.fit_predict(location)

# %%
df.location_cluster.value_counts()
# Out:
# 2    11231
# 1     9996
# 3     9717
# 0     9031
# 4     8904
# Name: location_cluster, dtype: int64

# %%
#Check the distribution of prices

plt.figure(figsize=(10,6))
plt.title("Distribution for Prices")
ax = sns.histplot(x = df['price'], color= 'b', label='Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(27,17))
plt.title("Distribution for Prices")
ax = sns.countplot(x = df['neighbourhood'])
plt.legend()
plt.xticks(rotation = 90)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#Check the distribution of prices without outliers

def distplot(feature, frame):
    plt.figure(figsize=(10,6))
    plt.title("Distribution for {}".format(feature))
    ax0 = sns.distplot(x = frame[frame['price'] <2500][feature], color= 'b', label='price')
    plt.legend()
    plt.show()
    
distplot('price', df)

# %%
#Remove the Outliers from the price column
from scipy import stats

cols = ['price'] # one or more

Q1 = df[cols].quantile(0.25)
Q3 = df[cols].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df[cols] < (Q1 - 1.5 * IQR)) |(df[cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
#new shape after removing price outliers
df.shape
# Out:
# (45908, 17)

# %%
#df.drop(df[df.availability_365 ==17].index)

# %%
df.loc[(df.minimum_nights >30),"minimum_nights"]=30

# %%
#Set the minimum nights to 30 maximum value
df = df[df["minimum_nights"] <31].copy()

# %%
#Get the length of the listings' names
df["name_length"]= df['name'].map(str).apply(len)

# %%
df.plot.scatter(x="name_length", y ="price" )
# Out:
# <AxesSubplot:xlabel='name_length', ylabel='price'>

# %%
#Remove names that have over 50 as length
#Indeed we see a lnear progression
df[df["name_length"]<50].plot.scatter(x="name_length", y ="price")
# Out:
# <AxesSubplot:xlabel='name_length', ylabel='price'>

# %%
df['name_length'].value_counts()
# Out:
# 50     3690
# 35     3204
# 49     2830
# 34     2454
# 48     2229
#        ...
# 179       1
# 150       1
# 93        1
# 98        1
# 76        1
# Name: name_length, Length: 81, dtype: int64

# %%
#drop the values that are over 125 as they appear to be outliers
name_col = ['name_length'] # one or more

Q1a = df[name_col].quantile(0.25)
Q3a = df[name_col].quantile(0.75)
IQRa = Q3a - Q1a

df = df[~((df[name_col] < (Q1a - 1.5 * IQRa)) |(df[name_col] > (Q3a + 1.5 * IQRa))).any(axis=1)]

# %%
#Remove reviews per month that are outliers
df['reviews_per_month'] = df[df['reviews_per_month'] < 17.5]['reviews_per_month']
# Out:
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/3355814640.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['reviews_per_month'] = df[df['reviews_per_month'] < 17.5]['reviews_per_month']

# %%
df['all_year_avail'] = df['availability_365']>353
df['low_avail'] = df['availability_365']< 12
df['no_reviews'] = df['reviews_per_month']==0
# Out:
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/4141838313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['all_year_avail'] = df['availability_365']>353
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/4141838313.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['low_avail'] = df['availability_365']< 12
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/4141838313.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['no_reviews'] = df['reviews_per_month']==0

# %%
df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan              Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan         East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan         Murray Hill  40.74767  -73.97500
# 6        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
# 8    MaryEllen           Manhattan     Upper West Side  40.80178  -73.96723
# 9          Ben           Manhattan           Chinatown  40.71344  -73.99037
#
#          room_type  price  ...  number_of_reviews  last_review  \
# 0     Private room    149  ...                  9   2018-10-19
# 1  Entire home/apt    225  ...                 45   2019-05-21
# 2     Private room    150  ...                  0  NotReviewed
# 3  Entire home/apt     89  ...                270   2019-07-05
# 4  Entire home/apt     80  ...                  9   2018-11-19
# 5  Entire home/apt    200  ...                 74   2019-06-22
# 6     Private room     60  ...                 49   2017-10-05
# 7     Private room     79  ...                430   2019-06-24
# 8     Private room     79  ...                118   2017-07-21
# 9  Entire home/apt    150  ...                160   2019-06-09
#
#   reviews_per_month  calculated_host_listings_count  availability_365  \
# 0              0.21                               6               365
# 1              0.38                               2               355
# 2              0.00                               1               365
# 3              4.64                               1               194
# 4              0.10                               1                 0
# 5              0.59                               1               129
# 6              0.40                               1                 0
# 7              3.47                               1               220
# 8              0.99                               1                 0
# 9              1.33                               4               188
#
#    location_cluster  name_length  all_year_avail  low_avail  no_reviews
# 0                 3           34            True      False       False
# 1                 3           21            True      False       False
# 2                 3           35            True      False        True
# 3                 3           31           False      False       False
# 4                 3           48           False       True       False
# 5                 3           41           False      False       False
# 6                 3           15           False       True       False
# 7                 3           32           False      False       False
# 8                 3           34           False       True       False
# 9                 3           34           False      False       False
#
# [10 rows x 21 columns]

# %%
#see the number of values in neighbourhood
neigh_count = df['neighbourhood'].value_counts()
select_neigh = neigh_count[neigh_count > 500].index.values

# %%
dfnh =df.groupby("neighbourhood").filter(lambda x: x['neighbourhood'].count() > 100)

# %%
len(dfnh["neighbourhood"])
# Out:
# 41884

# %%
dfnh.neighbourhood.unique()
# Out:
# array(['Kensington', 'Midtown', 'Harlem', 'Clinton Hill', 'East Harlem',
#        'Murray Hill', 'Bedford-Stuyvesant', "Hell's Kitchen",
#        'Upper West Side', 'Chinatown', 'South Slope', 'West Village',
#        'Williamsburg', 'Fort Greene', 'Chelsea', 'Crown Heights',
#        'Park Slope', 'Windsor Terrace', 'Inwood', 'East Village',
#        'Greenpoint', 'Bushwick', 'Flatbush', 'Lower East Side',
#        'Prospect-Lefferts Gardens', 'Long Island City', 'Kips Bay',
#        'SoHo', 'Upper East Side', 'Prospect Heights',
#        'Washington Heights', 'Woodside', 'Carroll Gardens', 'Gowanus',
#        'Flushing', 'Sunnyside', 'Financial District',
#        'Morningside Heights', 'Jamaica', 'Ridgewood', 'Ditmars Steinway',
#        'Greenwich Village', 'Little Italy', 'East Flatbush', 'Astoria',
#        'Boerum Hill', 'Brooklyn Heights', 'Forest Hills', 'Nolita',
#        'East New York', 'Theater District', 'Sheepshead Bay', 'Tribeca',
#        'Sunset Park', 'Gramercy', 'Elmhurst', 'Jackson Heights',
#        'Cypress Hills', 'Rego Park', 'Bay Ridge', 'Canarsie',
#        'East Elmhurst', 'Borough Park', 'Midwood', 'Maspeth'],
#       dtype=object)

# %%
len(select_neigh)
# Out:
# 22

# %%
#remove the neighborhoods that had really low numbers of listings
# df = df[df['neighbourhood'].isin(select_neigh)]

# %%
for idx, row in dfnh.iterrows():
    if dfnh.loc[idx, 'neighbourhood'] not in select_neigh:
        dfnh.loc[idx, 'neighbourhood'] = 'other'

# %%
#replace low frequency neighbourhood group names with other
# neigh_group_count = df['neighbourhood_group'].value_counts()
# low_neigh_group = neigh_group_count[neigh_group_count < 2000].index.values

# %%
# for idx, row in df1.iterrows():
#     if df1.loc[idx, 'neighbourhood_group'] in low_neigh_group:
#         df1.loc[idx, 'neighbourhood_group'] = 'other'

# %%
#get the categorical dummies without neighborhood first
df_encoded = pd.get_dummies(dfnh, columns = ['neighbourhood_group', 'room_type','neighbourhood','all_year_avail','low_avail','no_reviews','location_cluster'])
# 'all_year_avail','low_avail','no_reviews'
df_encoded.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name  latitude  longitude  price  minimum_nights  number_of_reviews  \
# 0         John  40.64749  -73.97237    149               1                  9
# 1     Jennifer  40.75362  -73.98377    225               1                 45
# 2    Elisabeth  40.80902  -73.94190    150               3                  0
# 3  LisaRoxanne  40.68514  -73.95976     89               1                270
# 4        Laura  40.79851  -73.94399     80              10                  9
#
#    last_review  ...  all_year_avail_True  low_avail_False  low_avail_True  \
# 0   2018-10-19  ...                    1                1               0
# 1   2019-05-21  ...                    1                1               0
# 2  NotReviewed  ...                    1                1               0
# 3   2019-07-05  ...                    0                1               0
# 4   2018-11-19  ...                    0                0               1
#
#    no_reviews_False  no_reviews_True  location_cluster_0  location_cluster_1  \
# 0                 1                0                   0                   0
# 1                 1                0                   0                   0
# 2                 0                1                   0                   0
# 3                 1                0                   0                   0
# 4                 1                0                   0                   0
#
#    location_cluster_2  location_cluster_3  location_cluster_4
# 0                   0                   1                   0
# 1                   0                   1                   0
# 2                   0                   1                   0
# 3                   0                   1                   0
# 4                   0                   1                   0
#
# [5 rows x 54 columns]

# %%
# df_encoded['location'] = df_encoded['longitude']*df_encoded['latitude']
# df_encoded['longitude square'] = df_encoded['longitude']*df_encoded['longitude']
# df_encoded['latitude square'] = df_encoded['latitude']*df_encoded['latitude']

# %%
df_encoded = df_encoded[dfnh['reviews_per_month'].notna()]

# %%
#plot the heatmap to check correlations amongst the variables
plt.figure(figsize=(12, 6))
corr = df_encoded[['price', 
           'number_of_reviews','reviews_per_month',
           'availability_365','calculated_host_listings_count','minimum_nights']].apply(lambda x: pd.factorize(x)[0]).corr()
display(corr)
ax = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, linewidths=.2, cmap="YlGnBu")
# Out:
#                                    price  number_of_reviews  \
# price                           1.000000           0.000311
# number_of_reviews               0.000311           1.000000
# reviews_per_month               0.008527           0.411396
# availability_365                0.040519           0.153355
# calculated_host_listings_count  0.193216          -0.099052
# minimum_nights                  0.016843          -0.069881
#
#                                 reviews_per_month  availability_365  \
# price                                    0.008527          0.040519
# number_of_reviews                        0.411396          0.153355
# reviews_per_month                        1.000000          0.256010
# availability_365                         0.256010          1.000000
# calculated_host_listings_count          -0.086331          0.079998
# minimum_nights                          -0.152688         -0.005551
#
#                                 calculated_host_listings_count  minimum_nights
# price                                                 0.193216        0.016843
# number_of_reviews                                    -0.099052       -0.069881
# reviews_per_month                                    -0.086331       -0.152688
# availability_365                                      0.079998       -0.005551
# calculated_host_listings_count                        1.000000        0.012861
# minimum_nights                                        0.012861        1.000000

# %%
#drop the irrelevant columns
df_encoded.drop(['name','id' ,
                 'host_id','host_name',
                 'last_review'],axis = 1, inplace = True)

# %%
X = df_encoded.loc[:, df_encoded.columns != 'price']

# %%
y = df_encoded['price']

# %%
#normalize the training data
norm_cols = ['availability_365','calculated_host_listings_count','name_length','minimum_nights',
             'reviews_per_month', 'number_of_reviews','number_of_reviews',
             'latitude','longitude']

# %%
X.head()
# Out:
#    latitude  longitude  minimum_nights  number_of_reviews  reviews_per_month  \
# 0  40.64749  -73.97237               1                  9               0.21
# 1  40.75362  -73.98377               1                 45               0.38
# 2  40.80902  -73.94190               3                  0               0.00
# 3  40.68514  -73.95976               1                270               4.64
# 4  40.79851  -73.94399              10                  9               0.10
#
#    calculated_host_listings_count  availability_365  name_length  \
# 0                               6               365           34
# 1                               2               355           21
# 2                               1               365           35
# 3                               1               194           31
# 4                               1                 0           48
#
#    neighbourhood_group_Brooklyn  neighbourhood_group_Manhattan  ...  \
# 0                             1                              0  ...
# 1                             0                              1  ...
# 2                             0                              1  ...
# 3                             1                              0  ...
# 4                             0                              1  ...
#
#    all_year_avail_True  low_avail_False  low_avail_True  no_reviews_False  \
# 0                    1                1               0                 1
# 1                    1                1               0                 1
# 2                    1                1               0                 0
# 3                    0                1               0                 1
# 4                    0                0               1                 1
#
#    no_reviews_True  location_cluster_0  location_cluster_1  \
# 0                0                   0                   0
# 1                0                   0                   0
# 2                1                   0                   0
# 3                0                   0                   0
# 4                0                   0                   0
#
#    location_cluster_2  location_cluster_3  location_cluster_4
# 0                   0                   1                   0
# 1                   0                   1                   0
# 2                   0                   1                   0
# 3                   0                   1                   0
# 4                   0                   1                   0
#
# [5 rows x 48 columns]

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler = StandardScaler()
X[norm_cols] = scaler.fit_transform(X[norm_cols])
# Out:
# C:\Users\oriar\anaconda3\lib\site-packages\pandas\core\frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
#split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# X_train[norm_cols] = scaler.fit_transform(X_train[norm_cols])
# X_test[norm_cols] = scaler.fit_transform(X_test[norm_cols])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_predict
from sklearn.linear_model import LinearRegression
from math import sqrt

cv = KFold(n_splits=10, random_state=0, shuffle=True)
classifier_pipeline = make_pipeline(StandardScaler(), KNeighborsRegressor(n_neighbors=20))
y_pred = cross_val_predict(classifier_pipeline, X_train, y_train, cv=cv)
print("RMSE: " + str(round(sqrt(mean_squared_error(y_train,y_pred)),2)))
print("R_squared: " + str(round(r2_score(y_train,y_pred),2)))
# Out:
# RMSE: 47.43
# R_squared: 0.51

# %%
#find the vairables that have low variabilities and filter them out
#the dummy variables are not included
small = [X_train.var()<0.03]

# %%
#check for the inclusion of features at different correlation values and the accuracy scores
vals = [0.03,0.02,0.01,0.005]
df_exp = df_encoded.drop(['reviews_per_month'],axis = 1)
for val in vals:
    features = abs(df_exp.corr()["price"][abs(df_exp.corr()["price"])>val].drop('price')).index.tolist()
    
    X_1 = df_exp.drop(['price'],axis = 1)
    X_1=X[features]
    
    print(features)

    y_pred = cross_val_predict(classifier_pipeline, X_1, y, cv=cv)
    print("RMSE: " + str(round(sqrt(mean_squared_error(y,y_pred)),2)))
    print("R_squared: " + str(round(r2_score(y,y_pred),2)))
# Out:
# ['latitude', 'longitude', 'minimum_nights', 'calculated_host_listings_count', 'availability_365', 'name_length', 'neighbourhood_group_Brooklyn', 'neighbourhood_group_Manhattan', 'neighbourhood_group_Queens', 'room_type_Entire home/apt', 'room_type_Private room', 'room_type_Shared room', 'neighbourhood_Astoria', 'neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Bushwick', 'neighbourhood_Chelsea', 'neighbourhood_Crown Heights', 'neighbourhood_East Village', 'neighbourhood_Financial District', 'neighbourhood_Flatbush', 'neighbourhood_Harlem', "neighbourhood_Hell's Kitchen", 'neighbourhood_Lower East Side', 'neighbourhood_Midtown', 'neighbourhood_Prospect-Lefferts Gardens', 'neighbourhood_Upper East Side', 'neighbourhood_Upper West Side', 'neighbourhood_Washington Heights', 'neighbourhood_West Village', 'neighbourhood_other', 'low_avail_False', 'low_avail_True', 'no_reviews_False', 'no_reviews_True', 'location_cluster_0', 'location_cluster_2', 'location_cluster_3']
# RMSE: 46.27
# R_squared: 0.54
# ['latitude', 'longitude', 'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count', 'availability_365', 'name_length', 'neighbourhood_group_Brooklyn', 'neighbourhood_group_Manhattan', 'neighbourhood_group_Queens', 'room_type_Entire home/apt', 'room_type_Private room', 'room_type_Shared room', 'neighbourhood_Astoria', 'neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Bushwick', 'neighbourhood_Chelsea', 'neighbourhood_Crown Heights', 'neighbourhood_East Harlem', 'neighbourhood_East Village', 'neighbourhood_Financial District', 'neighbourhood_Flatbush', 'neighbourhood_Harlem', "neighbourhood_Hell's Kitchen", 'neighbourhood_Lower East Side', 'neighbourhood_Midtown', 'neighbourhood_Prospect-Lefferts Gardens', 'neighbourhood_Upper East Side', 'neighbourhood_Upper West Side', 'neighbourhood_Washington Heights', 'neighbourhood_West Village', 'neighbourhood_other', 'all_year_avail_False', 'all_year_avail_True', 'low_avail_False', 'low_avail_True', 'no_reviews_False', 'no_reviews_True', 'location_cluster_0', 'location_cluster_2', 'location_cluster_3']
# RMSE: 46.45
# R_squared: 0.54
# ['latitude', 'longitude', 'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count', 'availability_365', 'name_length', 'neighbourhood_group_Brooklyn', 'neighbourhood_group_Manhattan', 'neighbourhood_group_Queens', 'room_type_Entire home/apt', 'room_type_Private room', 'room_type_Shared room', 'neighbourhood_Astoria', 'neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Bushwick', 'neighbourhood_Chelsea', 'neighbourhood_Crown Heights', 'neighbourhood_East Harlem', 'neighbourhood_East Village', 'neighbourhood_Financial District', 'neighbourhood_Flatbush', 'neighbourhood_Harlem', "neighbourhood_Hell's Kitchen", 'neighbourhood_Long Island City', 'neighbourhood_Lower East Side', 'neighbourhood_Midtown', 'neighbourhood_Prospect-Lefferts Gardens', 'neighbourhood_Upper East Side', 'neighbourhood_Upper West Side', 'neighbourhood_Washington Heights', 'neighbourhood_West Village', 'neighbourhood_Williamsburg', 'neighbourhood_other', 'all_year_avail_False', 'all_year_avail_True', 'low_avail_False', 'low_avail_True', 'no_reviews_False', 'no_reviews_True', 'location_cluster_0', 'location_cluster_1', 'location_cluster_2', 'location_cluster_3']
# RMSE: 46.69
# R_squared: 0.53
# ['latitude', 'longitude', 'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count', 'availability_365', 'name_length', 'neighbourhood_group_Brooklyn', 'neighbourhood_group_Manhattan', 'neighbourhood_group_Queens', 'room_type_Entire home/apt', 'room_type_Private room', 'room_type_Shared room', 'neighbourhood_Astoria', 'neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Bushwick', 'neighbourhood_Chelsea', 'neighbourhood_Crown Heights', 'neighbourhood_East Harlem', 'neighbourhood_East Village', 'neighbourhood_Financial District', 'neighbourhood_Flatbush', 'neighbourhood_Harlem', "neighbourhood_Hell's Kitchen", 'neighbourhood_Long Island City', 'neighbourhood_Lower East Side', 'neighbourhood_Midtown', 'neighbourhood_Prospect-Lefferts Gardens', 'neighbourhood_Upper East Side', 'neighbourhood_Upper West Side', 'neighbourhood_Washington Heights', 'neighbourhood_West Village', 'neighbourhood_Williamsburg', 'neighbourhood_other', 'all_year_avail_False', 'all_year_avail_True', 'low_avail_False', 'low_avail_True', 'no_reviews_False', 'no_reviews_True', 'location_cluster_0', 'location_cluster_1', 'location_cluster_2', 'location_cluster_3', 'location_cluster_4']
# RMSE: 47.09
# R_squared: 0.52

# %%
ls1 = ['minimum_nights', 'number_of_reviews', 'calculated_host_listings_count', 'availability_365', 'name_length', 'neighbourhood_group_Bronx', 'neighbourhood_group_Brooklyn', 'neighbourhood_group_Manhattan', 'neighbourhood_group_Queens', 'neighbourhood_group_Staten Island', 'room_type_Entire home/apt', 'room_type_Private room', 'room_type_Shared room', 'neighbourhood_Astoria', 'neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Bushwick', 'neighbourhood_Chelsea', 'neighbourhood_Crown Heights', 'neighbourhood_East Harlem', 'neighbourhood_East Village', 'neighbourhood_Financial District', 'neighbourhood_Flatbush', 'neighbourhood_Harlem', "neighbourhood_Hell's Kitchen", 'neighbourhood_Long Island City', 'neighbourhood_Lower East Side', 'neighbourhood_Midtown', 'neighbourhood_Prospect-Lefferts Gardens', 'neighbourhood_Upper East Side', 'neighbourhood_Upper West Side', 'neighbourhood_Washington Heights', 'neighbourhood_West Village', 'neighbourhood_Williamsburg', 'neighbourhood_other']
ls2 = ['minimum_nights', 'calculated_host_listings_count', 'availability_365', 'name_length', 'neighbourhood_group_Bronx', 'neighbourhood_group_Brooklyn', 'neighbourhood_group_Manhattan', 'neighbourhood_group_Queens', 'neighbourhood_group_Staten Island', 'room_type_Entire home/apt', 'room_type_Private room', 'room_type_Shared room', 'neighbourhood_Astoria', 'neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Bushwick', 'neighbourhood_Chelsea', 'neighbourhood_Crown Heights', 'neighbourhood_East Village', 'neighbourhood_Financial District', 'neighbourhood_Flatbush', 'neighbourhood_Harlem', "neighbourhood_Hell's Kitchen", 'neighbourhood_Lower East Side', 'neighbourhood_Midtown', 'neighbourhood_Prospect-Lefferts Gardens', 'neighbourhood_Upper East Side', 'neighbourhood_Upper West Side', 'neighbourhood_Washington Heights', 'neighbourhood_West Village', 'neighbourhood_other']

# %%
for item in ls1:
    if item not in ls2:
        print(item)
# Out:
# number_of_reviews
# neighbourhood_East Harlem
# neighbourhood_Long Island City
# neighbourhood_Williamsburg

# %%
X.isna().sum()
# Out:
# latitude                                   0
# longitude                                  0
# minimum_nights                             0
# number_of_reviews                          0
# reviews_per_month                          0
# calculated_host_listings_count             0
# availability_365                           0
# name_length                                0
# neighbourhood_group_Brooklyn               0
# neighbourhood_group_Manhattan              0
# neighbourhood_group_Queens                 0
# room_type_Entire home/apt                  0
# room_type_Private room                     0
# room_type_Shared room                      0
# neighbourhood_Astoria                      0
# neighbourhood_Bedford-Stuyvesant           0
# neighbourhood_Bushwick                     0
# neighbourhood_Chelsea                      0
# neighbourhood_Clinton Hill                 0
# neighbourhood_Crown Heights                0
# neighbourhood_East Harlem                  0
# neighbourhood_East Village                 0
# neighbourhood_Financial District           0
# neighbourhood_Flatbush                     0
# neighbourhood_Greenpoint                   0
# neighbourhood_Harlem                       0
# neighbourhood_Hell's Kitchen               0
# neighbourhood_Long Island City             0
# neighbourhood_Lower East Side              0
# neighbourhood_Midtown                      0
# neighbourhood_Prospect-Lefferts Gardens    0
# neighbourhood_Upper East Side              0
# neighbourhood_Upper West Side              0
# neighbourhood_Washington Heights           0
# neighbourhood_West Village                 0
# neighbourhood_Williamsburg                 0
# neighbourhood_other                        0
# all_year_avail_False                       0
# all_year_avail_True                        0
# low_avail_False                            0
# low_avail_True                             0
# no_reviews_False                           0
# no_reviews_True                            0
# location_cluster_0                         0
# location_cluster_1                         0
# location_cluster_2                         0
# location_cluster_3                         0
# location_cluster_4                         0
# dtype: int64

# %%
model_l = LinearRegression()

model_l.fit(X_train, y_train)
y_pred_l = model_l.predict(X_train)


l_mae = MAE(y_train, y_pred_l)
print("Training Set MAE:%4f" % l_mae)
l_mse = MSE(y_test, model_l.predict(X_test))
print("MSE:%4f" % l_mse)
print("RMSE Score: ", np.sqrt(l_mse))
print("R2 Score: {:.4f}".format(r2_score(y_test, model_l.predict(X_test))))
# Out:
# Training Set MAE:34.154531
# MSE:2238.025145
# RMSE Score:  47.30777044573423
# R2 Score: 0.5301

# %%
intercept = model_l.intercept_
features_importance = pd.DataFrame(model_l.coef_, X_train.columns, columns=['coefficient'])
features_importance.sort_values("coefficient", ascending = False)
# Out:
#                                          coefficient
# room_type_Entire home/apt                  59.729036
# neighbourhood_Williamsburg                 25.210968
# neighbourhood_group_Manhattan              20.688405
# neighbourhood_Midtown                      20.428206
# neighbourhood_Greenpoint                   18.437109
# neighbourhood_West Village                 16.020921
# neighbourhood_Clinton Hill                 10.950841
# neighbourhood_Chelsea                      10.424017
# no_reviews_True                             5.866550
# low_avail_False                             5.764641
# neighbourhood_Hell's Kitchen                5.742365
# all_year_avail_True                         4.854143
# availability_365                            4.525723
# neighbourhood_Long Island City              4.365423
# calculated_host_listings_count              3.741913
# name_length                                 3.030832
# location_cluster_4                          2.795765
# location_cluster_3                          2.658406
# neighbourhood_Bushwick                      2.531915
# neighbourhood_Upper West Side               1.876420
# neighbourhood_Upper East Side               0.377982
# neighbourhood_other                        -0.527496
# neighbourhood_Astoria                      -0.527506
# reviews_per_month                          -1.155820
# location_cluster_0                         -1.424416
# neighbourhood_Bedford-Stuyvesant           -1.653155
# number_of_reviews                          -1.693394
# location_cluster_2                         -1.981350
# location_cluster_1                         -2.048406
# neighbourhood_East Village                 -2.367665
# latitude                                   -2.777629
# neighbourhood_Crown Heights                -2.957208
# neighbourhood_group_Queens                 -4.591334
# neighbourhood_Financial District           -4.838453
# all_year_avail_False                       -4.854143
# low_avail_True                             -5.764641
# no_reviews_False                           -5.866550
# neighbourhood_Lower East Side              -5.938853
# longitude                                  -9.629848
# minimum_nights                            -10.026709
# neighbourhood_East Harlem                 -11.889358
# neighbourhood_Prospect-Lefferts Gardens   -14.722337
# room_type_Private room                    -16.053301
# neighbourhood_group_Brooklyn              -16.097071
# neighbourhood_Flatbush                    -20.206810
# neighbourhood_Harlem                      -20.877498
# neighbourhood_Washington Heights          -29.859828
# room_type_Shared room                     -43.675735

# %%
from sklearn.linear_model import Lasso

regL1 = Lasso(alpha=0.01)
regL1.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.01)

# %%
regL1.score(X_train,y_train)
# Out:
# 0.5359484738430573

# %%
y_predL1= regL1.predict(X_test)
print(np.sqrt(MSE(y_test,y_predL1)))
# Out:
# 47.31646647032261

# %%
from itertools import combinations
column_list = X_train.columns
interactions = list(combinations(column_list, 2))
interactions
# Out:
# [('latitude', 'longitude'),
#  ('latitude', 'minimum_nights'),
#  ('latitude', 'number_of_reviews'),
#  ('latitude', 'reviews_per_month'),
#  ('latitude', 'calculated_host_listings_count'),
#  ('latitude', 'availability_365'),
#  ('latitude', 'name_length'),
#  ('latitude', 'neighbourhood_group_Brooklyn'),
#  ('latitude', 'neighbourhood_group_Manhattan'),
#  ('latitude', 'neighbourhood_group_Queens'),
#  ('latitude', 'room_type_Entire home/apt'),
#  ('latitude', 'room_type_Private room'),
#  ('latitude', 'room_type_Shared room'),
#  ('latitude', 'neighbourhood_Astoria'),
#  ('latitude', 'neighbourhood_Bedford-Stuyvesant'),
#  ('latitude', 'neighbourhood_Bushwick'),
#  ('latitude', 'neighbourhood_Chelsea'),
#  ('latitude', 'neighbourhood_Clinton Hill'),
#  ('latitude', 'neighbourhood_Crown Heights'),
#  ('latitude', 'neighbourhood_East Harlem'),
#  ('latitude', 'neighbourhood_East Village'),
#  ('latitude', 'neighbourhood_Financial District'),
#  ('latitude', 'neighbourhood_Flatbush'),
#  ('latitude', 'neighbourhood_Greenpoint'),
#  ('latitude', 'neighbourhood_Harlem'),
#  ('latitude', "neighbourhood_Hell's Kitchen"),
#  ('latitude', 'neighbourhood_Long Island City'),
#  ('latitude', 'neighbourhood_Lower East Side'),
#  ('latitude', 'neighbourhood_Midtown'),
#  ('latitude', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('latitude', 'neighbourhood_Upper East Side'),
#  ('latitude', 'neighbourhood_Upper West Side'),
#  ('latitude', 'neighbourhood_Washington Heights'),
#  ('latitude', 'neighbourhood_West Village'),
#  ('latitude', 'neighbourhood_Williamsburg'),
#  ('latitude', 'neighbourhood_other'),
#  ('latitude', 'all_year_avail_False'),
#  ('latitude', 'all_year_avail_True'),
#  ('latitude', 'low_avail_False'),
#  ('latitude', 'low_avail_True'),
#  ('latitude', 'no_reviews_False'),
#  ('latitude', 'no_reviews_True'),
#  ('latitude', 'location_cluster_0'),
#  ('latitude', 'location_cluster_1'),
#  ('latitude', 'location_cluster_2'),
#  ('latitude', 'location_cluster_3'),
#  ('latitude', 'location_cluster_4'),
#  ('longitude', 'minimum_nights'),
#  ('longitude', 'number_of_reviews'),
#  ('longitude', 'reviews_per_month'),
#  ('longitude', 'calculated_host_listings_count'),
#  ('longitude', 'availability_365'),
#  ('longitude', 'name_length'),
#  ('longitude', 'neighbourhood_group_Brooklyn'),
#  ('longitude', 'neighbourhood_group_Manhattan'),
#  ('longitude', 'neighbourhood_group_Queens'),
#  ('longitude', 'room_type_Entire home/apt'),
#  ('longitude', 'room_type_Private room'),
#  ('longitude', 'room_type_Shared room'),
#  ('longitude', 'neighbourhood_Astoria'),
#  ('longitude', 'neighbourhood_Bedford-Stuyvesant'),
#  ('longitude', 'neighbourhood_Bushwick'),
#  ('longitude', 'neighbourhood_Chelsea'),
#  ('longitude', 'neighbourhood_Clinton Hill'),
#  ('longitude', 'neighbourhood_Crown Heights'),
#  ('longitude', 'neighbourhood_East Harlem'),
#  ('longitude', 'neighbourhood_East Village'),
#  ('longitude', 'neighbourhood_Financial District'),
#  ('longitude', 'neighbourhood_Flatbush'),
#  ('longitude', 'neighbourhood_Greenpoint'),
#  ('longitude', 'neighbourhood_Harlem'),
#  ('longitude', "neighbourhood_Hell's Kitchen"),
#  ('longitude', 'neighbourhood_Long Island City'),
#  ('longitude', 'neighbourhood_Lower East Side'),
#  ('longitude', 'neighbourhood_Midtown'),
#  ('longitude', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('longitude', 'neighbourhood_Upper East Side'),
#  ('longitude', 'neighbourhood_Upper West Side'),
#  ('longitude', 'neighbourhood_Washington Heights'),
#  ('longitude', 'neighbourhood_West Village'),
#  ('longitude', 'neighbourhood_Williamsburg'),
#  ('longitude', 'neighbourhood_other'),
#  ('longitude', 'all_year_avail_False'),
#  ('longitude', 'all_year_avail_True'),
#  ('longitude', 'low_avail_False'),
#  ('longitude', 'low_avail_True'),
#  ('longitude', 'no_reviews_False'),
#  ('longitude', 'no_reviews_True'),
#  ('longitude', 'location_cluster_0'),
#  ('longitude', 'location_cluster_1'),
#  ('longitude', 'location_cluster_2'),
#  ('longitude', 'location_cluster_3'),
#  ('longitude', 'location_cluster_4'),
#  ('minimum_nights', 'number_of_reviews'),
#  ('minimum_nights', 'reviews_per_month'),
#  ('minimum_nights', 'calculated_host_listings_count'),
#  ('minimum_nights', 'availability_365'),
#  ('minimum_nights', 'name_length'),
#  ('minimum_nights', 'neighbourhood_group_Brooklyn'),
#  ('minimum_nights', 'neighbourhood_group_Manhattan'),
#  ('minimum_nights', 'neighbourhood_group_Queens'),
#  ('minimum_nights', 'room_type_Entire home/apt'),
#  ('minimum_nights', 'room_type_Private room'),
#  ('minimum_nights', 'room_type_Shared room'),
#  ('minimum_nights', 'neighbourhood_Astoria'),
#  ('minimum_nights', 'neighbourhood_Bedford-Stuyvesant'),
#  ('minimum_nights', 'neighbourhood_Bushwick'),
#  ('minimum_nights', 'neighbourhood_Chelsea'),
#  ('minimum_nights', 'neighbourhood_Clinton Hill'),
#  ('minimum_nights', 'neighbourhood_Crown Heights'),
#  ('minimum_nights', 'neighbourhood_East Harlem'),
#  ('minimum_nights', 'neighbourhood_East Village'),
#  ('minimum_nights', 'neighbourhood_Financial District'),
#  ('minimum_nights', 'neighbourhood_Flatbush'),
#  ('minimum_nights', 'neighbourhood_Greenpoint'),
#  ('minimum_nights', 'neighbourhood_Harlem'),
#  ('minimum_nights', "neighbourhood_Hell's Kitchen"),
#  ('minimum_nights', 'neighbourhood_Long Island City'),
#  ('minimum_nights', 'neighbourhood_Lower East Side'),
#  ('minimum_nights', 'neighbourhood_Midtown'),
#  ('minimum_nights', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('minimum_nights', 'neighbourhood_Upper East Side'),
#  ('minimum_nights', 'neighbourhood_Upper West Side'),
#  ('minimum_nights', 'neighbourhood_Washington Heights'),
#  ('minimum_nights', 'neighbourhood_West Village'),
#  ('minimum_nights', 'neighbourhood_Williamsburg'),
#  ('minimum_nights', 'neighbourhood_other'),
#  ('minimum_nights', 'all_year_avail_False'),
#  ('minimum_nights', 'all_year_avail_True'),
#  ('minimum_nights', 'low_avail_False'),
#  ('minimum_nights', 'low_avail_True'),
#  ('minimum_nights', 'no_reviews_False'),
#  ('minimum_nights', 'no_reviews_True'),
#  ('minimum_nights', 'location_cluster_0'),
#  ('minimum_nights', 'location_cluster_1'),
#  ('minimum_nights', 'location_cluster_2'),
#  ('minimum_nights', 'location_cluster_3'),
#  ('minimum_nights', 'location_cluster_4'),
#  ('number_of_reviews', 'reviews_per_month'),
#  ('number_of_reviews', 'calculated_host_listings_count'),
#  ('number_of_reviews', 'availability_365'),
#  ('number_of_reviews', 'name_length'),
#  ('number_of_reviews', 'neighbourhood_group_Brooklyn'),
#  ('number_of_reviews', 'neighbourhood_group_Manhattan'),
#  ('number_of_reviews', 'neighbourhood_group_Queens'),
#  ('number_of_reviews', 'room_type_Entire home/apt'),
#  ('number_of_reviews', 'room_type_Private room'),
#  ('number_of_reviews', 'room_type_Shared room'),
#  ('number_of_reviews', 'neighbourhood_Astoria'),
#  ('number_of_reviews', 'neighbourhood_Bedford-Stuyvesant'),
#  ('number_of_reviews', 'neighbourhood_Bushwick'),
#  ('number_of_reviews', 'neighbourhood_Chelsea'),
#  ('number_of_reviews', 'neighbourhood_Clinton Hill'),
#  ('number_of_reviews', 'neighbourhood_Crown Heights'),
#  ('number_of_reviews', 'neighbourhood_East Harlem'),
#  ('number_of_reviews', 'neighbourhood_East Village'),
#  ('number_of_reviews', 'neighbourhood_Financial District'),
#  ('number_of_reviews', 'neighbourhood_Flatbush'),
#  ('number_of_reviews', 'neighbourhood_Greenpoint'),
#  ('number_of_reviews', 'neighbourhood_Harlem'),
#  ('number_of_reviews', "neighbourhood_Hell's Kitchen"),
#  ('number_of_reviews', 'neighbourhood_Long Island City'),
#  ('number_of_reviews', 'neighbourhood_Lower East Side'),
#  ('number_of_reviews', 'neighbourhood_Midtown'),
#  ('number_of_reviews', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('number_of_reviews', 'neighbourhood_Upper East Side'),
#  ('number_of_reviews', 'neighbourhood_Upper West Side'),
#  ('number_of_reviews', 'neighbourhood_Washington Heights'),
#  ('number_of_reviews', 'neighbourhood_West Village'),
#  ('number_of_reviews', 'neighbourhood_Williamsburg'),
#  ('number_of_reviews', 'neighbourhood_other'),
#  ('number_of_reviews', 'all_year_avail_False'),
#  ('number_of_reviews', 'all_year_avail_True'),
#  ('number_of_reviews', 'low_avail_False'),
#  ('number_of_reviews', 'low_avail_True'),
#  ('number_of_reviews', 'no_reviews_False'),
#  ('number_of_reviews', 'no_reviews_True'),
#  ('number_of_reviews', 'location_cluster_0'),
#  ('number_of_reviews', 'location_cluster_1'),
#  ('number_of_reviews', 'location_cluster_2'),
#  ('number_of_reviews', 'location_cluster_3'),
#  ('number_of_reviews', 'location_cluster_4'),
#  ('reviews_per_month', 'calculated_host_listings_count'),
#  ('reviews_per_month', 'availability_365'),
#  ('reviews_per_month', 'name_length'),
#  ('reviews_per_month', 'neighbourhood_group_Brooklyn'),
#  ('reviews_per_month', 'neighbourhood_group_Manhattan'),
#  ('reviews_per_month', 'neighbourhood_group_Queens'),
#  ('reviews_per_month', 'room_type_Entire home/apt'),
#  ('reviews_per_month', 'room_type_Private room'),
#  ('reviews_per_month', 'room_type_Shared room'),
#  ('reviews_per_month', 'neighbourhood_Astoria'),
#  ('reviews_per_month', 'neighbourhood_Bedford-Stuyvesant'),
#  ('reviews_per_month', 'neighbourhood_Bushwick'),
#  ('reviews_per_month', 'neighbourhood_Chelsea'),
#  ('reviews_per_month', 'neighbourhood_Clinton Hill'),
#  ('reviews_per_month', 'neighbourhood_Crown Heights'),
#  ('reviews_per_month', 'neighbourhood_East Harlem'),
#  ('reviews_per_month', 'neighbourhood_East Village'),
#  ('reviews_per_month', 'neighbourhood_Financial District'),
#  ('reviews_per_month', 'neighbourhood_Flatbush'),
#  ('reviews_per_month', 'neighbourhood_Greenpoint'),
#  ('reviews_per_month', 'neighbourhood_Harlem'),
#  ('reviews_per_month', "neighbourhood_Hell's Kitchen"),
#  ('reviews_per_month', 'neighbourhood_Long Island City'),
#  ('reviews_per_month', 'neighbourhood_Lower East Side'),
#  ('reviews_per_month', 'neighbourhood_Midtown'),
#  ('reviews_per_month', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('reviews_per_month', 'neighbourhood_Upper East Side'),
#  ('reviews_per_month', 'neighbourhood_Upper West Side'),
#  ('reviews_per_month', 'neighbourhood_Washington Heights'),
#  ('reviews_per_month', 'neighbourhood_West Village'),
#  ('reviews_per_month', 'neighbourhood_Williamsburg'),
#  ('reviews_per_month', 'neighbourhood_other'),
#  ('reviews_per_month', 'all_year_avail_False'),
#  ('reviews_per_month', 'all_year_avail_True'),
#  ('reviews_per_month', 'low_avail_False'),
#  ('reviews_per_month', 'low_avail_True'),
#  ('reviews_per_month', 'no_reviews_False'),
#  ('reviews_per_month', 'no_reviews_True'),
#  ('reviews_per_month', 'location_cluster_0'),
#  ('reviews_per_month', 'location_cluster_1'),
#  ('reviews_per_month', 'location_cluster_2'),
#  ('reviews_per_month', 'location_cluster_3'),
#  ('reviews_per_month', 'location_cluster_4'),
#  ('calculated_host_listings_count', 'availability_365'),
#  ('calculated_host_listings_count', 'name_length'),
#  ('calculated_host_listings_count', 'neighbourhood_group_Brooklyn'),
#  ('calculated_host_listings_count', 'neighbourhood_group_Manhattan'),
#  ('calculated_host_listings_count', 'neighbourhood_group_Queens'),
#  ('calculated_host_listings_count', 'room_type_Entire home/apt'),
#  ('calculated_host_listings_count', 'room_type_Private room'),
#  ('calculated_host_listings_count', 'room_type_Shared room'),
#  ('calculated_host_listings_count', 'neighbourhood_Astoria'),
#  ('calculated_host_listings_count', 'neighbourhood_Bedford-Stuyvesant'),
#  ('calculated_host_listings_count', 'neighbourhood_Bushwick'),
#  ('calculated_host_listings_count', 'neighbourhood_Chelsea'),
#  ('calculated_host_listings_count', 'neighbourhood_Clinton Hill'),
#  ('calculated_host_listings_count', 'neighbourhood_Crown Heights'),
#  ('calculated_host_listings_count', 'neighbourhood_East Harlem'),
#  ('calculated_host_listings_count', 'neighbourhood_East Village'),
#  ('calculated_host_listings_count', 'neighbourhood_Financial District'),
#  ('calculated_host_listings_count', 'neighbourhood_Flatbush'),
#  ('calculated_host_listings_count', 'neighbourhood_Greenpoint'),
#  ('calculated_host_listings_count', 'neighbourhood_Harlem'),
#  ('calculated_host_listings_count', "neighbourhood_Hell's Kitchen"),
#  ('calculated_host_listings_count', 'neighbourhood_Long Island City'),
#  ('calculated_host_listings_count', 'neighbourhood_Lower East Side'),
#  ('calculated_host_listings_count', 'neighbourhood_Midtown'),
#  ('calculated_host_listings_count', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('calculated_host_listings_count', 'neighbourhood_Upper East Side'),
#  ('calculated_host_listings_count', 'neighbourhood_Upper West Side'),
#  ('calculated_host_listings_count', 'neighbourhood_Washington Heights'),
#  ('calculated_host_listings_count', 'neighbourhood_West Village'),
#  ('calculated_host_listings_count', 'neighbourhood_Williamsburg'),
#  ('calculated_host_listings_count', 'neighbourhood_other'),
#  ('calculated_host_listings_count', 'all_year_avail_False'),
#  ('calculated_host_listings_count', 'all_year_avail_True'),
#  ('calculated_host_listings_count', 'low_avail_False'),
#  ('calculated_host_listings_count', 'low_avail_True'),
#  ('calculated_host_listings_count', 'no_reviews_False'),
#  ('calculated_host_listings_count', 'no_reviews_True'),
#  ('calculated_host_listings_count', 'location_cluster_0'),
#  ('calculated_host_listings_count', 'location_cluster_1'),
#  ('calculated_host_listings_count', 'location_cluster_2'),
#  ('calculated_host_listings_count', 'location_cluster_3'),
#  ('calculated_host_listings_count', 'location_cluster_4'),
#  ('availability_365', 'name_length'),
#  ('availability_365', 'neighbourhood_group_Brooklyn'),
#  ('availability_365', 'neighbourhood_group_Manhattan'),
#  ('availability_365', 'neighbourhood_group_Queens'),
#  ('availability_365', 'room_type_Entire home/apt'),
#  ('availability_365', 'room_type_Private room'),
#  ('availability_365', 'room_type_Shared room'),
#  ('availability_365', 'neighbourhood_Astoria'),
#  ('availability_365', 'neighbourhood_Bedford-Stuyvesant'),
#  ('availability_365', 'neighbourhood_Bushwick'),
#  ('availability_365', 'neighbourhood_Chelsea'),
#  ('availability_365', 'neighbourhood_Clinton Hill'),
#  ('availability_365', 'neighbourhood_Crown Heights'),
#  ('availability_365', 'neighbourhood_East Harlem'),
#  ('availability_365', 'neighbourhood_East Village'),
#  ('availability_365', 'neighbourhood_Financial District'),
#  ('availability_365', 'neighbourhood_Flatbush'),
#  ('availability_365', 'neighbourhood_Greenpoint'),
#  ('availability_365', 'neighbourhood_Harlem'),
#  ('availability_365', "neighbourhood_Hell's Kitchen"),
#  ('availability_365', 'neighbourhood_Long Island City'),
#  ('availability_365', 'neighbourhood_Lower East Side'),
#  ('availability_365', 'neighbourhood_Midtown'),
#  ('availability_365', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('availability_365', 'neighbourhood_Upper East Side'),
#  ('availability_365', 'neighbourhood_Upper West Side'),
#  ('availability_365', 'neighbourhood_Washington Heights'),
#  ('availability_365', 'neighbourhood_West Village'),
#  ('availability_365', 'neighbourhood_Williamsburg'),
#  ('availability_365', 'neighbourhood_other'),
#  ('availability_365', 'all_year_avail_False'),
#  ('availability_365', 'all_year_avail_True'),
#  ('availability_365', 'low_avail_False'),
#  ('availability_365', 'low_avail_True'),
#  ('availability_365', 'no_reviews_False'),
#  ('availability_365', 'no_reviews_True'),
#  ('availability_365', 'location_cluster_0'),
#  ('availability_365', 'location_cluster_1'),
#  ('availability_365', 'location_cluster_2'),
#  ('availability_365', 'location_cluster_3'),
#  ('availability_365', 'location_cluster_4'),
#  ('name_length', 'neighbourhood_group_Brooklyn'),
#  ('name_length', 'neighbourhood_group_Manhattan'),
#  ('name_length', 'neighbourhood_group_Queens'),
#  ('name_length', 'room_type_Entire home/apt'),
#  ('name_length', 'room_type_Private room'),
#  ('name_length', 'room_type_Shared room'),
#  ('name_length', 'neighbourhood_Astoria'),
#  ('name_length', 'neighbourhood_Bedford-Stuyvesant'),
#  ('name_length', 'neighbourhood_Bushwick'),
#  ('name_length', 'neighbourhood_Chelsea'),
#  ('name_length', 'neighbourhood_Clinton Hill'),
#  ('name_length', 'neighbourhood_Crown Heights'),
#  ('name_length', 'neighbourhood_East Harlem'),
#  ('name_length', 'neighbourhood_East Village'),
#  ('name_length', 'neighbourhood_Financial District'),
#  ('name_length', 'neighbourhood_Flatbush'),
#  ('name_length', 'neighbourhood_Greenpoint'),
#  ('name_length', 'neighbourhood_Harlem'),
#  ('name_length', "neighbourhood_Hell's Kitchen"),
#  ('name_length', 'neighbourhood_Long Island City'),
#  ('name_length', 'neighbourhood_Lower East Side'),
#  ('name_length', 'neighbourhood_Midtown'),
#  ('name_length', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('name_length', 'neighbourhood_Upper East Side'),
#  ('name_length', 'neighbourhood_Upper West Side'),
#  ('name_length', 'neighbourhood_Washington Heights'),
#  ('name_length', 'neighbourhood_West Village'),
#  ('name_length', 'neighbourhood_Williamsburg'),
#  ('name_length', 'neighbourhood_other'),
#  ('name_length', 'all_year_avail_False'),
#  ('name_length', 'all_year_avail_True'),
#  ('name_length', 'low_avail_False'),
#  ('name_length', 'low_avail_True'),
#  ('name_length', 'no_reviews_False'),
#  ('name_length', 'no_reviews_True'),
#  ('name_length', 'location_cluster_0'),
#  ('name_length', 'location_cluster_1'),
#  ('name_length', 'location_cluster_2'),
#  ('name_length', 'location_cluster_3'),
#  ('name_length', 'location_cluster_4'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_group_Manhattan'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_group_Queens'),
#  ('neighbourhood_group_Brooklyn', 'room_type_Entire home/apt'),
#  ('neighbourhood_group_Brooklyn', 'room_type_Private room'),
#  ('neighbourhood_group_Brooklyn', 'room_type_Shared room'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Astoria'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Bedford-Stuyvesant'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Bushwick'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Chelsea'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Clinton Hill'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Crown Heights'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_East Harlem'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_East Village'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Financial District'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Flatbush'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Greenpoint'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Harlem'),
#  ('neighbourhood_group_Brooklyn', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Long Island City'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Midtown'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_West Village'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_group_Brooklyn', 'neighbourhood_other'),
#  ('neighbourhood_group_Brooklyn', 'all_year_avail_False'),
#  ('neighbourhood_group_Brooklyn', 'all_year_avail_True'),
#  ('neighbourhood_group_Brooklyn', 'low_avail_False'),
#  ('neighbourhood_group_Brooklyn', 'low_avail_True'),
#  ('neighbourhood_group_Brooklyn', 'no_reviews_False'),
#  ('neighbourhood_group_Brooklyn', 'no_reviews_True'),
#  ('neighbourhood_group_Brooklyn', 'location_cluster_0'),
#  ('neighbourhood_group_Brooklyn', 'location_cluster_1'),
#  ('neighbourhood_group_Brooklyn', 'location_cluster_2'),
#  ('neighbourhood_group_Brooklyn', 'location_cluster_3'),
#  ('neighbourhood_group_Brooklyn', 'location_cluster_4'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_group_Queens'),
#  ('neighbourhood_group_Manhattan', 'room_type_Entire home/apt'),
#  ('neighbourhood_group_Manhattan', 'room_type_Private room'),
#  ('neighbourhood_group_Manhattan', 'room_type_Shared room'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Astoria'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Bedford-Stuyvesant'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Bushwick'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Chelsea'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Clinton Hill'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Crown Heights'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_East Harlem'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_East Village'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Financial District'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Flatbush'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Greenpoint'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Harlem'),
#  ('neighbourhood_group_Manhattan', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Long Island City'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Midtown'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_West Village'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_group_Manhattan', 'neighbourhood_other'),
#  ('neighbourhood_group_Manhattan', 'all_year_avail_False'),
#  ('neighbourhood_group_Manhattan', 'all_year_avail_True'),
#  ('neighbourhood_group_Manhattan', 'low_avail_False'),
#  ('neighbourhood_group_Manhattan', 'low_avail_True'),
#  ('neighbourhood_group_Manhattan', 'no_reviews_False'),
#  ('neighbourhood_group_Manhattan', 'no_reviews_True'),
#  ('neighbourhood_group_Manhattan', 'location_cluster_0'),
#  ('neighbourhood_group_Manhattan', 'location_cluster_1'),
#  ('neighbourhood_group_Manhattan', 'location_cluster_2'),
#  ('neighbourhood_group_Manhattan', 'location_cluster_3'),
#  ('neighbourhood_group_Manhattan', 'location_cluster_4'),
#  ('neighbourhood_group_Queens', 'room_type_Entire home/apt'),
#  ('neighbourhood_group_Queens', 'room_type_Private room'),
#  ('neighbourhood_group_Queens', 'room_type_Shared room'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Astoria'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Bedford-Stuyvesant'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Bushwick'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Chelsea'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Clinton Hill'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Crown Heights'),
#  ('neighbourhood_group_Queens', 'neighbourhood_East Harlem'),
#  ('neighbourhood_group_Queens', 'neighbourhood_East Village'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Financial District'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Flatbush'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Greenpoint'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Harlem'),
#  ('neighbourhood_group_Queens', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_group_Queens', 'neighbourhood_Long Island City'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Midtown'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_group_Queens', 'neighbourhood_West Village'),
#  ('neighbourhood_group_Queens', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_group_Queens', 'neighbourhood_other'),
#  ('neighbourhood_group_Queens', 'all_year_avail_False'),
#  ('neighbourhood_group_Queens', 'all_year_avail_True'),
#  ('neighbourhood_group_Queens', 'low_avail_False'),
#  ('neighbourhood_group_Queens', 'low_avail_True'),
#  ('neighbourhood_group_Queens', 'no_reviews_False'),
#  ('neighbourhood_group_Queens', 'no_reviews_True'),
#  ('neighbourhood_group_Queens', 'location_cluster_0'),
#  ('neighbourhood_group_Queens', 'location_cluster_1'),
#  ('neighbourhood_group_Queens', 'location_cluster_2'),
#  ('neighbourhood_group_Queens', 'location_cluster_3'),
#  ('neighbourhood_group_Queens', 'location_cluster_4'),
#  ('room_type_Entire home/apt', 'room_type_Private room'),
#  ('room_type_Entire home/apt', 'room_type_Shared room'),
#  ('room_type_Entire home/apt', 'neighbourhood_Astoria'),
#  ('room_type_Entire home/apt', 'neighbourhood_Bedford-Stuyvesant'),
#  ('room_type_Entire home/apt', 'neighbourhood_Bushwick'),
#  ('room_type_Entire home/apt', 'neighbourhood_Chelsea'),
#  ('room_type_Entire home/apt', 'neighbourhood_Clinton Hill'),
#  ('room_type_Entire home/apt', 'neighbourhood_Crown Heights'),
#  ('room_type_Entire home/apt', 'neighbourhood_East Harlem'),
#  ('room_type_Entire home/apt', 'neighbourhood_East Village'),
#  ('room_type_Entire home/apt', 'neighbourhood_Financial District'),
#  ('room_type_Entire home/apt', 'neighbourhood_Flatbush'),
#  ('room_type_Entire home/apt', 'neighbourhood_Greenpoint'),
#  ('room_type_Entire home/apt', 'neighbourhood_Harlem'),
#  ('room_type_Entire home/apt', "neighbourhood_Hell's Kitchen"),
#  ('room_type_Entire home/apt', 'neighbourhood_Long Island City'),
#  ('room_type_Entire home/apt', 'neighbourhood_Lower East Side'),
#  ('room_type_Entire home/apt', 'neighbourhood_Midtown'),
#  ('room_type_Entire home/apt', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('room_type_Entire home/apt', 'neighbourhood_Upper East Side'),
#  ('room_type_Entire home/apt', 'neighbourhood_Upper West Side'),
#  ('room_type_Entire home/apt', 'neighbourhood_Washington Heights'),
#  ('room_type_Entire home/apt', 'neighbourhood_West Village'),
#  ('room_type_Entire home/apt', 'neighbourhood_Williamsburg'),
#  ('room_type_Entire home/apt', 'neighbourhood_other'),
#  ('room_type_Entire home/apt', 'all_year_avail_False'),
#  ('room_type_Entire home/apt', 'all_year_avail_True'),
#  ('room_type_Entire home/apt', 'low_avail_False'),
#  ('room_type_Entire home/apt', 'low_avail_True'),
#  ('room_type_Entire home/apt', 'no_reviews_False'),
#  ('room_type_Entire home/apt', 'no_reviews_True'),
#  ('room_type_Entire home/apt', 'location_cluster_0'),
#  ('room_type_Entire home/apt', 'location_cluster_1'),
#  ('room_type_Entire home/apt', 'location_cluster_2'),
#  ('room_type_Entire home/apt', 'location_cluster_3'),
#  ('room_type_Entire home/apt', 'location_cluster_4'),
#  ('room_type_Private room', 'room_type_Shared room'),
#  ('room_type_Private room', 'neighbourhood_Astoria'),
#  ('room_type_Private room', 'neighbourhood_Bedford-Stuyvesant'),
#  ('room_type_Private room', 'neighbourhood_Bushwick'),
#  ('room_type_Private room', 'neighbourhood_Chelsea'),
#  ('room_type_Private room', 'neighbourhood_Clinton Hill'),
#  ('room_type_Private room', 'neighbourhood_Crown Heights'),
#  ('room_type_Private room', 'neighbourhood_East Harlem'),
#  ('room_type_Private room', 'neighbourhood_East Village'),
#  ('room_type_Private room', 'neighbourhood_Financial District'),
#  ('room_type_Private room', 'neighbourhood_Flatbush'),
#  ('room_type_Private room', 'neighbourhood_Greenpoint'),
#  ('room_type_Private room', 'neighbourhood_Harlem'),
#  ('room_type_Private room', "neighbourhood_Hell's Kitchen"),
#  ('room_type_Private room', 'neighbourhood_Long Island City'),
#  ('room_type_Private room', 'neighbourhood_Lower East Side'),
#  ('room_type_Private room', 'neighbourhood_Midtown'),
#  ('room_type_Private room', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('room_type_Private room', 'neighbourhood_Upper East Side'),
#  ('room_type_Private room', 'neighbourhood_Upper West Side'),
#  ('room_type_Private room', 'neighbourhood_Washington Heights'),
#  ('room_type_Private room', 'neighbourhood_West Village'),
#  ('room_type_Private room', 'neighbourhood_Williamsburg'),
#  ('room_type_Private room', 'neighbourhood_other'),
#  ('room_type_Private room', 'all_year_avail_False'),
#  ('room_type_Private room', 'all_year_avail_True'),
#  ('room_type_Private room', 'low_avail_False'),
#  ('room_type_Private room', 'low_avail_True'),
#  ('room_type_Private room', 'no_reviews_False'),
#  ('room_type_Private room', 'no_reviews_True'),
#  ('room_type_Private room', 'location_cluster_0'),
#  ('room_type_Private room', 'location_cluster_1'),
#  ('room_type_Private room', 'location_cluster_2'),
#  ('room_type_Private room', 'location_cluster_3'),
#  ('room_type_Private room', 'location_cluster_4'),
#  ('room_type_Shared room', 'neighbourhood_Astoria'),
#  ('room_type_Shared room', 'neighbourhood_Bedford-Stuyvesant'),
#  ('room_type_Shared room', 'neighbourhood_Bushwick'),
#  ('room_type_Shared room', 'neighbourhood_Chelsea'),
#  ('room_type_Shared room', 'neighbourhood_Clinton Hill'),
#  ('room_type_Shared room', 'neighbourhood_Crown Heights'),
#  ('room_type_Shared room', 'neighbourhood_East Harlem'),
#  ('room_type_Shared room', 'neighbourhood_East Village'),
#  ('room_type_Shared room', 'neighbourhood_Financial District'),
#  ('room_type_Shared room', 'neighbourhood_Flatbush'),
#  ('room_type_Shared room', 'neighbourhood_Greenpoint'),
#  ('room_type_Shared room', 'neighbourhood_Harlem'),
#  ('room_type_Shared room', "neighbourhood_Hell's Kitchen"),
#  ('room_type_Shared room', 'neighbourhood_Long Island City'),
#  ('room_type_Shared room', 'neighbourhood_Lower East Side'),
#  ('room_type_Shared room', 'neighbourhood_Midtown'),
#  ('room_type_Shared room', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('room_type_Shared room', 'neighbourhood_Upper East Side'),
#  ('room_type_Shared room', 'neighbourhood_Upper West Side'),
#  ('room_type_Shared room', 'neighbourhood_Washington Heights'),
#  ('room_type_Shared room', 'neighbourhood_West Village'),
#  ('room_type_Shared room', 'neighbourhood_Williamsburg'),
#  ('room_type_Shared room', 'neighbourhood_other'),
#  ('room_type_Shared room', 'all_year_avail_False'),
#  ('room_type_Shared room', 'all_year_avail_True'),
#  ('room_type_Shared room', 'low_avail_False'),
#  ('room_type_Shared room', 'low_avail_True'),
#  ('room_type_Shared room', 'no_reviews_False'),
#  ('room_type_Shared room', 'no_reviews_True'),
#  ('room_type_Shared room', 'location_cluster_0'),
#  ('room_type_Shared room', 'location_cluster_1'),
#  ('room_type_Shared room', 'location_cluster_2'),
#  ('room_type_Shared room', 'location_cluster_3'),
#  ('room_type_Shared room', 'location_cluster_4'),
#  ('neighbourhood_Astoria', 'neighbourhood_Bedford-Stuyvesant'),
#  ('neighbourhood_Astoria', 'neighbourhood_Bushwick'),
#  ('neighbourhood_Astoria', 'neighbourhood_Chelsea'),
#  ('neighbourhood_Astoria', 'neighbourhood_Clinton Hill'),
#  ('neighbourhood_Astoria', 'neighbourhood_Crown Heights'),
#  ('neighbourhood_Astoria', 'neighbourhood_East Harlem'),
#  ('neighbourhood_Astoria', 'neighbourhood_East Village'),
#  ('neighbourhood_Astoria', 'neighbourhood_Financial District'),
#  ('neighbourhood_Astoria', 'neighbourhood_Flatbush'),
#  ('neighbourhood_Astoria', 'neighbourhood_Greenpoint'),
#  ('neighbourhood_Astoria', 'neighbourhood_Harlem'),
#  ('neighbourhood_Astoria', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_Astoria', 'neighbourhood_Long Island City'),
#  ('neighbourhood_Astoria', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_Astoria', 'neighbourhood_Midtown'),
#  ('neighbourhood_Astoria', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_Astoria', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_Astoria', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Astoria', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_Astoria', 'neighbourhood_West Village'),
#  ('neighbourhood_Astoria', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Astoria', 'neighbourhood_other'),
#  ('neighbourhood_Astoria', 'all_year_avail_False'),
#  ('neighbourhood_Astoria', 'all_year_avail_True'),
#  ('neighbourhood_Astoria', 'low_avail_False'),
#  ('neighbourhood_Astoria', 'low_avail_True'),
#  ('neighbourhood_Astoria', 'no_reviews_False'),
#  ('neighbourhood_Astoria', 'no_reviews_True'),
#  ('neighbourhood_Astoria', 'location_cluster_0'),
#  ('neighbourhood_Astoria', 'location_cluster_1'),
#  ('neighbourhood_Astoria', 'location_cluster_2'),
#  ('neighbourhood_Astoria', 'location_cluster_3'),
#  ('neighbourhood_Astoria', 'location_cluster_4'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Bushwick'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Chelsea'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Clinton Hill'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Crown Heights'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_East Harlem'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_East Village'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Financial District'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Flatbush'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Greenpoint'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Harlem'),
#  ('neighbourhood_Bedford-Stuyvesant', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Long Island City'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Midtown'),
#  ('neighbourhood_Bedford-Stuyvesant',
#   'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_West Village'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Bedford-Stuyvesant', 'neighbourhood_other'),
#  ('neighbourhood_Bedford-Stuyvesant', 'all_year_avail_False'),
#  ('neighbourhood_Bedford-Stuyvesant', 'all_year_avail_True'),
#  ('neighbourhood_Bedford-Stuyvesant', 'low_avail_False'),
#  ('neighbourhood_Bedford-Stuyvesant', 'low_avail_True'),
#  ('neighbourhood_Bedford-Stuyvesant', 'no_reviews_False'),
#  ('neighbourhood_Bedford-Stuyvesant', 'no_reviews_True'),
#  ('neighbourhood_Bedford-Stuyvesant', 'location_cluster_0'),
#  ('neighbourhood_Bedford-Stuyvesant', 'location_cluster_1'),
#  ('neighbourhood_Bedford-Stuyvesant', 'location_cluster_2'),
#  ('neighbourhood_Bedford-Stuyvesant', 'location_cluster_3'),
#  ('neighbourhood_Bedford-Stuyvesant', 'location_cluster_4'),
#  ('neighbourhood_Bushwick', 'neighbourhood_Chelsea'),
#  ('neighbourhood_Bushwick', 'neighbourhood_Clinton Hill'),
#  ('neighbourhood_Bushwick', 'neighbourhood_Crown Heights'),
#  ('neighbourhood_Bushwick', 'neighbourhood_East Harlem'),
#  ('neighbourhood_Bushwick', 'neighbourhood_East Village'),
#  ('neighbourhood_Bushwick', 'neighbourhood_Financial District'),
#  ('neighbourhood_Bushwick', 'neighbourhood_Flatbush'),
#  ('neighbourhood_Bushwick', 'neighbourhood_Greenpoint'),
#  ('neighbourhood_Bushwick', 'neighbourhood_Harlem'),
#  ('neighbourhood_Bushwick', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_Bushwick', 'neighbourhood_Long Island City'),
#  ('neighbourhood_Bushwick', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_Bushwick', 'neighbourhood_Midtown'),
#  ('neighbourhood_Bushwick', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_Bushwick', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_Bushwick', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Bushwick', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_Bushwick', 'neighbourhood_West Village'),
#  ('neighbourhood_Bushwick', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Bushwick', 'neighbourhood_other'),
#  ('neighbourhood_Bushwick', 'all_year_avail_False'),
#  ('neighbourhood_Bushwick', 'all_year_avail_True'),
#  ('neighbourhood_Bushwick', 'low_avail_False'),
#  ('neighbourhood_Bushwick', 'low_avail_True'),
#  ('neighbourhood_Bushwick', 'no_reviews_False'),
#  ('neighbourhood_Bushwick', 'no_reviews_True'),
#  ('neighbourhood_Bushwick', 'location_cluster_0'),
#  ('neighbourhood_Bushwick', 'location_cluster_1'),
#  ('neighbourhood_Bushwick', 'location_cluster_2'),
#  ('neighbourhood_Bushwick', 'location_cluster_3'),
#  ('neighbourhood_Bushwick', 'location_cluster_4'),
#  ('neighbourhood_Chelsea', 'neighbourhood_Clinton Hill'),
#  ('neighbourhood_Chelsea', 'neighbourhood_Crown Heights'),
#  ('neighbourhood_Chelsea', 'neighbourhood_East Harlem'),
#  ('neighbourhood_Chelsea', 'neighbourhood_East Village'),
#  ('neighbourhood_Chelsea', 'neighbourhood_Financial District'),
#  ('neighbourhood_Chelsea', 'neighbourhood_Flatbush'),
#  ('neighbourhood_Chelsea', 'neighbourhood_Greenpoint'),
#  ('neighbourhood_Chelsea', 'neighbourhood_Harlem'),
#  ('neighbourhood_Chelsea', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_Chelsea', 'neighbourhood_Long Island City'),
#  ('neighbourhood_Chelsea', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_Chelsea', 'neighbourhood_Midtown'),
#  ('neighbourhood_Chelsea', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_Chelsea', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_Chelsea', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Chelsea', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_Chelsea', 'neighbourhood_West Village'),
#  ('neighbourhood_Chelsea', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Chelsea', 'neighbourhood_other'),
#  ('neighbourhood_Chelsea', 'all_year_avail_False'),
#  ('neighbourhood_Chelsea', 'all_year_avail_True'),
#  ('neighbourhood_Chelsea', 'low_avail_False'),
#  ('neighbourhood_Chelsea', 'low_avail_True'),
#  ('neighbourhood_Chelsea', 'no_reviews_False'),
#  ('neighbourhood_Chelsea', 'no_reviews_True'),
#  ('neighbourhood_Chelsea', 'location_cluster_0'),
#  ('neighbourhood_Chelsea', 'location_cluster_1'),
#  ('neighbourhood_Chelsea', 'location_cluster_2'),
#  ('neighbourhood_Chelsea', 'location_cluster_3'),
#  ('neighbourhood_Chelsea', 'location_cluster_4'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_Crown Heights'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_East Harlem'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_East Village'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_Financial District'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_Flatbush'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_Greenpoint'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_Harlem'),
#  ('neighbourhood_Clinton Hill', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_Long Island City'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_Midtown'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_West Village'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Clinton Hill', 'neighbourhood_other'),
#  ('neighbourhood_Clinton Hill', 'all_year_avail_False'),
#  ('neighbourhood_Clinton Hill', 'all_year_avail_True'),
#  ('neighbourhood_Clinton Hill', 'low_avail_False'),
#  ('neighbourhood_Clinton Hill', 'low_avail_True'),
#  ('neighbourhood_Clinton Hill', 'no_reviews_False'),
#  ('neighbourhood_Clinton Hill', 'no_reviews_True'),
#  ('neighbourhood_Clinton Hill', 'location_cluster_0'),
#  ('neighbourhood_Clinton Hill', 'location_cluster_1'),
#  ('neighbourhood_Clinton Hill', 'location_cluster_2'),
#  ('neighbourhood_Clinton Hill', 'location_cluster_3'),
#  ('neighbourhood_Clinton Hill', 'location_cluster_4'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_East Harlem'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_East Village'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_Financial District'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_Flatbush'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_Greenpoint'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_Harlem'),
#  ('neighbourhood_Crown Heights', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_Crown Heights', 'neighbourhood_Long Island City'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_Midtown'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_West Village'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Crown Heights', 'neighbourhood_other'),
#  ('neighbourhood_Crown Heights', 'all_year_avail_False'),
#  ('neighbourhood_Crown Heights', 'all_year_avail_True'),
#  ('neighbourhood_Crown Heights', 'low_avail_False'),
#  ('neighbourhood_Crown Heights', 'low_avail_True'),
#  ('neighbourhood_Crown Heights', 'no_reviews_False'),
#  ('neighbourhood_Crown Heights', 'no_reviews_True'),
#  ('neighbourhood_Crown Heights', 'location_cluster_0'),
#  ('neighbourhood_Crown Heights', 'location_cluster_1'),
#  ('neighbourhood_Crown Heights', 'location_cluster_2'),
#  ('neighbourhood_Crown Heights', 'location_cluster_3'),
#  ('neighbourhood_Crown Heights', 'location_cluster_4'),
#  ('neighbourhood_East Harlem', 'neighbourhood_East Village'),
#  ('neighbourhood_East Harlem', 'neighbourhood_Financial District'),
#  ('neighbourhood_East Harlem', 'neighbourhood_Flatbush'),
#  ('neighbourhood_East Harlem', 'neighbourhood_Greenpoint'),
#  ('neighbourhood_East Harlem', 'neighbourhood_Harlem'),
#  ('neighbourhood_East Harlem', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_East Harlem', 'neighbourhood_Long Island City'),
#  ('neighbourhood_East Harlem', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_East Harlem', 'neighbourhood_Midtown'),
#  ('neighbourhood_East Harlem', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_East Harlem', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_East Harlem', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_East Harlem', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_East Harlem', 'neighbourhood_West Village'),
#  ('neighbourhood_East Harlem', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_East Harlem', 'neighbourhood_other'),
#  ('neighbourhood_East Harlem', 'all_year_avail_False'),
#  ('neighbourhood_East Harlem', 'all_year_avail_True'),
#  ('neighbourhood_East Harlem', 'low_avail_False'),
#  ('neighbourhood_East Harlem', 'low_avail_True'),
#  ('neighbourhood_East Harlem', 'no_reviews_False'),
#  ('neighbourhood_East Harlem', 'no_reviews_True'),
#  ('neighbourhood_East Harlem', 'location_cluster_0'),
#  ('neighbourhood_East Harlem', 'location_cluster_1'),
#  ('neighbourhood_East Harlem', 'location_cluster_2'),
#  ('neighbourhood_East Harlem', 'location_cluster_3'),
#  ('neighbourhood_East Harlem', 'location_cluster_4'),
#  ('neighbourhood_East Village', 'neighbourhood_Financial District'),
#  ('neighbourhood_East Village', 'neighbourhood_Flatbush'),
#  ('neighbourhood_East Village', 'neighbourhood_Greenpoint'),
#  ('neighbourhood_East Village', 'neighbourhood_Harlem'),
#  ('neighbourhood_East Village', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_East Village', 'neighbourhood_Long Island City'),
#  ('neighbourhood_East Village', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_East Village', 'neighbourhood_Midtown'),
#  ('neighbourhood_East Village', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_East Village', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_East Village', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_East Village', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_East Village', 'neighbourhood_West Village'),
#  ('neighbourhood_East Village', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_East Village', 'neighbourhood_other'),
#  ('neighbourhood_East Village', 'all_year_avail_False'),
#  ('neighbourhood_East Village', 'all_year_avail_True'),
#  ('neighbourhood_East Village', 'low_avail_False'),
#  ('neighbourhood_East Village', 'low_avail_True'),
#  ('neighbourhood_East Village', 'no_reviews_False'),
#  ('neighbourhood_East Village', 'no_reviews_True'),
#  ('neighbourhood_East Village', 'location_cluster_0'),
#  ('neighbourhood_East Village', 'location_cluster_1'),
#  ('neighbourhood_East Village', 'location_cluster_2'),
#  ('neighbourhood_East Village', 'location_cluster_3'),
#  ('neighbourhood_East Village', 'location_cluster_4'),
#  ('neighbourhood_Financial District', 'neighbourhood_Flatbush'),
#  ('neighbourhood_Financial District', 'neighbourhood_Greenpoint'),
#  ('neighbourhood_Financial District', 'neighbourhood_Harlem'),
#  ('neighbourhood_Financial District', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_Financial District', 'neighbourhood_Long Island City'),
#  ('neighbourhood_Financial District', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_Financial District', 'neighbourhood_Midtown'),
#  ('neighbourhood_Financial District',
#   'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_Financial District', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_Financial District', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Financial District', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_Financial District', 'neighbourhood_West Village'),
#  ('neighbourhood_Financial District', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Financial District', 'neighbourhood_other'),
#  ('neighbourhood_Financial District', 'all_year_avail_False'),
#  ('neighbourhood_Financial District', 'all_year_avail_True'),
#  ('neighbourhood_Financial District', 'low_avail_False'),
#  ('neighbourhood_Financial District', 'low_avail_True'),
#  ('neighbourhood_Financial District', 'no_reviews_False'),
#  ('neighbourhood_Financial District', 'no_reviews_True'),
#  ('neighbourhood_Financial District', 'location_cluster_0'),
#  ('neighbourhood_Financial District', 'location_cluster_1'),
#  ('neighbourhood_Financial District', 'location_cluster_2'),
#  ('neighbourhood_Financial District', 'location_cluster_3'),
#  ('neighbourhood_Financial District', 'location_cluster_4'),
#  ('neighbourhood_Flatbush', 'neighbourhood_Greenpoint'),
#  ('neighbourhood_Flatbush', 'neighbourhood_Harlem'),
#  ('neighbourhood_Flatbush', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_Flatbush', 'neighbourhood_Long Island City'),
#  ('neighbourhood_Flatbush', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_Flatbush', 'neighbourhood_Midtown'),
#  ('neighbourhood_Flatbush', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_Flatbush', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_Flatbush', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Flatbush', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_Flatbush', 'neighbourhood_West Village'),
#  ('neighbourhood_Flatbush', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Flatbush', 'neighbourhood_other'),
#  ('neighbourhood_Flatbush', 'all_year_avail_False'),
#  ('neighbourhood_Flatbush', 'all_year_avail_True'),
#  ('neighbourhood_Flatbush', 'low_avail_False'),
#  ('neighbourhood_Flatbush', 'low_avail_True'),
#  ('neighbourhood_Flatbush', 'no_reviews_False'),
#  ('neighbourhood_Flatbush', 'no_reviews_True'),
#  ('neighbourhood_Flatbush', 'location_cluster_0'),
#  ('neighbourhood_Flatbush', 'location_cluster_1'),
#  ('neighbourhood_Flatbush', 'location_cluster_2'),
#  ('neighbourhood_Flatbush', 'location_cluster_3'),
#  ('neighbourhood_Flatbush', 'location_cluster_4'),
#  ('neighbourhood_Greenpoint', 'neighbourhood_Harlem'),
#  ('neighbourhood_Greenpoint', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_Greenpoint', 'neighbourhood_Long Island City'),
#  ('neighbourhood_Greenpoint', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_Greenpoint', 'neighbourhood_Midtown'),
#  ('neighbourhood_Greenpoint', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_Greenpoint', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_Greenpoint', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Greenpoint', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_Greenpoint', 'neighbourhood_West Village'),
#  ('neighbourhood_Greenpoint', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Greenpoint', 'neighbourhood_other'),
#  ('neighbourhood_Greenpoint', 'all_year_avail_False'),
#  ('neighbourhood_Greenpoint', 'all_year_avail_True'),
#  ('neighbourhood_Greenpoint', 'low_avail_False'),
#  ('neighbourhood_Greenpoint', 'low_avail_True'),
#  ('neighbourhood_Greenpoint', 'no_reviews_False'),
#  ('neighbourhood_Greenpoint', 'no_reviews_True'),
#  ('neighbourhood_Greenpoint', 'location_cluster_0'),
#  ('neighbourhood_Greenpoint', 'location_cluster_1'),
#  ('neighbourhood_Greenpoint', 'location_cluster_2'),
#  ('neighbourhood_Greenpoint', 'location_cluster_3'),
#  ('neighbourhood_Greenpoint', 'location_cluster_4'),
#  ('neighbourhood_Harlem', "neighbourhood_Hell's Kitchen"),
#  ('neighbourhood_Harlem', 'neighbourhood_Long Island City'),
#  ('neighbourhood_Harlem', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_Harlem', 'neighbourhood_Midtown'),
#  ('neighbourhood_Harlem', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_Harlem', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_Harlem', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Harlem', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_Harlem', 'neighbourhood_West Village'),
#  ('neighbourhood_Harlem', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Harlem', 'neighbourhood_other'),
#  ('neighbourhood_Harlem', 'all_year_avail_False'),
#  ('neighbourhood_Harlem', 'all_year_avail_True'),
#  ('neighbourhood_Harlem', 'low_avail_False'),
#  ('neighbourhood_Harlem', 'low_avail_True'),
#  ('neighbourhood_Harlem', 'no_reviews_False'),
#  ('neighbourhood_Harlem', 'no_reviews_True'),
#  ('neighbourhood_Harlem', 'location_cluster_0'),
#  ('neighbourhood_Harlem', 'location_cluster_1'),
#  ('neighbourhood_Harlem', 'location_cluster_2'),
#  ('neighbourhood_Harlem', 'location_cluster_3'),
#  ('neighbourhood_Harlem', 'location_cluster_4'),
#  ("neighbourhood_Hell's Kitchen", 'neighbourhood_Long Island City'),
#  ("neighbourhood_Hell's Kitchen", 'neighbourhood_Lower East Side'),
#  ("neighbourhood_Hell's Kitchen", 'neighbourhood_Midtown'),
#  ("neighbourhood_Hell's Kitchen", 'neighbourhood_Prospect-Lefferts Gardens'),
#  ("neighbourhood_Hell's Kitchen", 'neighbourhood_Upper East Side'),
#  ("neighbourhood_Hell's Kitchen", 'neighbourhood_Upper West Side'),
#  ("neighbourhood_Hell's Kitchen", 'neighbourhood_Washington Heights'),
#  ("neighbourhood_Hell's Kitchen", 'neighbourhood_West Village'),
#  ("neighbourhood_Hell's Kitchen", 'neighbourhood_Williamsburg'),
#  ("neighbourhood_Hell's Kitchen", 'neighbourhood_other'),
#  ("neighbourhood_Hell's Kitchen", 'all_year_avail_False'),
#  ("neighbourhood_Hell's Kitchen", 'all_year_avail_True'),
#  ("neighbourhood_Hell's Kitchen", 'low_avail_False'),
#  ("neighbourhood_Hell's Kitchen", 'low_avail_True'),
#  ("neighbourhood_Hell's Kitchen", 'no_reviews_False'),
#  ("neighbourhood_Hell's Kitchen", 'no_reviews_True'),
#  ("neighbourhood_Hell's Kitchen", 'location_cluster_0'),
#  ("neighbourhood_Hell's Kitchen", 'location_cluster_1'),
#  ("neighbourhood_Hell's Kitchen", 'location_cluster_2'),
#  ("neighbourhood_Hell's Kitchen", 'location_cluster_3'),
#  ("neighbourhood_Hell's Kitchen", 'location_cluster_4'),
#  ('neighbourhood_Long Island City', 'neighbourhood_Lower East Side'),
#  ('neighbourhood_Long Island City', 'neighbourhood_Midtown'),
#  ('neighbourhood_Long Island City', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_Long Island City', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_Long Island City', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Long Island City', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_Long Island City', 'neighbourhood_West Village'),
#  ('neighbourhood_Long Island City', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Long Island City', 'neighbourhood_other'),
#  ('neighbourhood_Long Island City', 'all_year_avail_False'),
#  ('neighbourhood_Long Island City', 'all_year_avail_True'),
#  ('neighbourhood_Long Island City', 'low_avail_False'),
#  ('neighbourhood_Long Island City', 'low_avail_True'),
#  ('neighbourhood_Long Island City', 'no_reviews_False'),
#  ('neighbourhood_Long Island City', 'no_reviews_True'),
#  ('neighbourhood_Long Island City', 'location_cluster_0'),
#  ('neighbourhood_Long Island City', 'location_cluster_1'),
#  ('neighbourhood_Long Island City', 'location_cluster_2'),
#  ('neighbourhood_Long Island City', 'location_cluster_3'),
#  ('neighbourhood_Long Island City', 'location_cluster_4'),
#  ('neighbourhood_Lower East Side', 'neighbourhood_Midtown'),
#  ('neighbourhood_Lower East Side', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_Lower East Side', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_Lower East Side', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Lower East Side', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_Lower East Side', 'neighbourhood_West Village'),
#  ('neighbourhood_Lower East Side', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Lower East Side', 'neighbourhood_other'),
#  ('neighbourhood_Lower East Side', 'all_year_avail_False'),
#  ('neighbourhood_Lower East Side', 'all_year_avail_True'),
#  ('neighbourhood_Lower East Side', 'low_avail_False'),
#  ('neighbourhood_Lower East Side', 'low_avail_True'),
#  ('neighbourhood_Lower East Side', 'no_reviews_False'),
#  ('neighbourhood_Lower East Side', 'no_reviews_True'),
#  ('neighbourhood_Lower East Side', 'location_cluster_0'),
#  ('neighbourhood_Lower East Side', 'location_cluster_1'),
#  ('neighbourhood_Lower East Side', 'location_cluster_2'),
#  ('neighbourhood_Lower East Side', 'location_cluster_3'),
#  ('neighbourhood_Lower East Side', 'location_cluster_4'),
#  ('neighbourhood_Midtown', 'neighbourhood_Prospect-Lefferts Gardens'),
#  ('neighbourhood_Midtown', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_Midtown', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Midtown', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_Midtown', 'neighbourhood_West Village'),
#  ('neighbourhood_Midtown', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Midtown', 'neighbourhood_other'),
#  ('neighbourhood_Midtown', 'all_year_avail_False'),
#  ('neighbourhood_Midtown', 'all_year_avail_True'),
#  ('neighbourhood_Midtown', 'low_avail_False'),
#  ('neighbourhood_Midtown', 'low_avail_True'),
#  ('neighbourhood_Midtown', 'no_reviews_False'),
#  ('neighbourhood_Midtown', 'no_reviews_True'),
#  ('neighbourhood_Midtown', 'location_cluster_0'),
#  ('neighbourhood_Midtown', 'location_cluster_1'),
#  ('neighbourhood_Midtown', 'location_cluster_2'),
#  ('neighbourhood_Midtown', 'location_cluster_3'),
#  ('neighbourhood_Midtown', 'location_cluster_4'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'neighbourhood_Upper East Side'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Prospect-Lefferts Gardens',
#   'neighbourhood_Washington Heights'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'neighbourhood_West Village'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'neighbourhood_other'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'all_year_avail_False'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'all_year_avail_True'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'low_avail_False'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'low_avail_True'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'no_reviews_False'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'no_reviews_True'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'location_cluster_0'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'location_cluster_1'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'location_cluster_2'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'location_cluster_3'),
#  ('neighbourhood_Prospect-Lefferts Gardens', 'location_cluster_4'),
#  ('neighbourhood_Upper East Side', 'neighbourhood_Upper West Side'),
#  ('neighbourhood_Upper East Side', 'neighbourhood_Washington Heights'),
#  ('neighbourhood_Upper East Side', 'neighbourhood_West Village'),
#  ('neighbourhood_Upper East Side', 'neighbourhood_Williamsburg'),
#  ('neighbourhood_Upper East Side', 'neighbourhood_other'),
#  ('neighbourhood_Upper East Side', 'all_year_avail_False'),
#  ('neighbourhood_Upper East Side', 'all_year_avail_True'),
#  ('neighbourhood_Upper East Side', 'low_avail_False'),
#  ...]

# %%
interaction_dict = {}
for interaction in interactions:
    X_train_int = X_train
    X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
    lr2 = LinearRegression()
    lr2.fit(X_train_int, y_train)
    interaction_dict[lr2.score(X_train_int, y_train)] = interaction
# Out:
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# ...
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/505259918.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_int['int']= X_train_int[interaction[0]]*X_train_int[interaction[1]]

# %%
top_5 = sorted(interaction_dict.keys(),reverse = True)[:5]
for interaction in top_5:
    print(interaction_dict[interaction])
# Out:
# ('latitude', 'neighbourhood_group_Brooklyn')
# ('latitude', 'neighbourhood_group_Manhattan')
# ('longitude', 'neighbourhood_group_Manhattan')
# ('calculated_host_listings_count', 'name_length')
# ('longitude', 'neighbourhood_group_Queens')

# %%
X_train_ad = X_train
X_test_ad = X_test
# X_train_ad['listingXlength'] = X_train_ad['calculated_host_listings_count']* X_train_ad['name_length']
# X_test_ad['listingXlength'] = X_test_ad['calculated_host_listings_count']* X_test_ad['name_length']
# X_train_ad['typeXwilliamsburg'] = X_train_ad['room_type_Private room']* X_train_ad['neighbourhood_Williamsburg']
# X_test_ad['typeXwilliamsburg'] = X_test_ad['room_type_Private room']* X_test_ad['neighbourhood_Williamsburg']
X_train_ad['latitude*Manhattan'] = X_train_ad['neighbourhood_group_Manhattan']* X_train_ad['latitude']
X_test_ad['latitude*Manhattan'] = X_test_ad['neighbourhood_group_Manhattan']* X_test_ad['latitude']
X_train_ad['latitude*Brooklyn'] = X_train_ad['neighbourhood_group_Brooklyn']* X_train_ad['latitude']
X_test_ad['latitude*Brooklyn'] = X_test_ad['neighbourhood_group_Brooklyn']* X_test_ad['latitude']
# Out:
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/923943113.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_ad['latitude*Manhattan'] = X_train_ad['neighbourhood_group_Manhattan']* X_train_ad['latitude']
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/923943113.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_ad['latitude*Manhattan'] = X_test_ad['neighbourhood_group_Manhattan']* X_test_ad['latitude']
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/923943113.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_ad['latitude*Brooklyn'] = X_train_ad['neighbourhood_group_Brooklyn']* X_train_ad['latitude']
# C:\Users\oriar\AppData\Local\Temp/ipykernel_14004/923943113.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_ad['latitude*Brooklyn'] = X_test_ad['neighbourhood_group_Brooklyn']* X_test_ad['latitude']

# %%
lst1 = X_train_ad.columns.to_list()
lst2 = X_test_ad.columns.to_list()

for item in lst1:
    if item not in lst2:
        print(item)
# Out:
# int

# %%
X_train_ad.drop(['int'],axis=1, inplace=True)
# Out:
# C:\Users\oriar\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
lr3 = LinearRegression()
lr3.fit(X_train_ad, y_train)


a_mae = MAE(y_train, lr3.predict(X_train_ad))
print("Training Set MAE:%4f" % a_mae)
a_mse = MSE(y_test, lr3.predict(X_test_ad))
print("MSE:%4f" % a_mse)
print("RMSE Score: ", np.sqrt(a_mse))
print("R2 Score: {:.4f}".format(r2_score(y_test, lr3.predict(X_test_ad))))
# Out:
# Training Set MAE:33.744972
# MSE:2195.984278
# RMSE Score:  46.861330305611915
# R2 Score: 0.5389

# %%
# neigh_1 = ['neighbourhood_group_Bronx',
#  'neighbourhood_group_Brooklyn',
#  'neighbourhood_group_Manhattan',
#  'neighbourhood_group_Queens',
#  'neighbourhood_group_Staten Island',
#  'neighbourhood_Allerton',
#  'neighbourhood_Arden Heights',
#  'neighbourhood_Arrochar',
#  'neighbourhood_Arverne',
#  'neighbourhood_Astoria']


# df['neigh1'] = X[neigh_1].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)

# %%
# neigh_2 = ['neighbourhood_Bath Beach',
#  'neighbourhood_Battery Park City',
#  'neighbourhood_Bay Ridge',
#  'neighbourhood_Bay Terrace',
#  'neighbourhood_Bay Terrace, Staten Island',
#  'neighbourhood_Baychester',
#  'neighbourhood_Bayside',
#  'neighbourhood_Bayswater',
#  'neighbourhood_Bedford-Stuyvesant',
#  'neighbourhood_Belle Harbor',
#  'neighbourhood_Bellerose',
#  'neighbourhood_Belmont',
#  'neighbourhood_Bensonhurst',
#  'neighbourhood_Bergen Beach',
#  'neighbourhood_Boerum Hill',
#  'neighbourhood_Borough Park',
#  'neighbourhood_Breezy Point',
#  'neighbourhood_Briarwood',
#  'neighbourhood_Brighton Beach',
#  'neighbourhood_Bronxdale',
#  'neighbourhood_Brooklyn Heights',
#  'neighbourhood_Brownsville',
#  "neighbourhood_Bull's Head"]


# df['neigh2'] = X[neigh_2].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)

# %%
# neigh_3 = ['neighbourhood_Cambria Heights',
#  'neighbourhood_Canarsie',
#  'neighbourhood_Carroll Gardens',
#  'neighbourhood_Castle Hill',
#  'neighbourhood_Castleton Corners',
#  'neighbourhood_Chelsea',
#  'neighbourhood_Chinatown',
#  'neighbourhood_City Island',
#  'neighbourhood_Civic Center',
#  'neighbourhood_Claremont Village',
#  'neighbourhood_Clason Point',
#  'neighbourhood_Clifton',
#  'neighbourhood_Clinton Hill',
#  'neighbourhood_Co-op City',
#  'neighbourhood_Cobble Hill',
#  'neighbourhood_College Point',
#  'neighbourhood_Columbia St',
#  'neighbourhood_Concord',
#  'neighbourhood_Concourse',
#  'neighbourhood_Concourse Village',
#  'neighbourhood_Coney Island',
#  'neighbourhood_Corona',
#  'neighbourhood_Crown Heights',
#  'neighbourhood_Cypress Hills']


# df['neigh3'] = X[neigh_3].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)

# %%
# neigh_4 = []


# df['neigh4'] = X[neigh_4].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)

# %%
#Use the ensemble learning's gradient boosting regressor to predict the salary
#There are a lot of parameters to specify in this model
#n_estimators:the number of sequential trees to be molded 
model_g = ensemble.GradientBoostingRegressor(
    n_estimators = 700, #n_estimators:the number of sequential trees to be molded 
    learning_rate = 0.02, #shrinks the contribution of each tree by this rate
    max_depth = 9, #how deep the trees can be
    min_samples_leaf = 8, #min number of samples required to split an internal node
    max_features = 0.35, 
    loss='huber', #refers to the loss function to be minimized in each split
    random_state = 0 #ensures the results are consistent
)

model_g.fit(X_train_ad, y_train)

g_mae = MAE(y_train, model_g.predict(X_train_ad))
print("Training Set MAE:%4f" % g_mae)
g_mse = MSE(y_test, model_g.predict(X_test_ad))
print("MSE:%4f" % g_mse)
print("RMSE Score: ", np.sqrt(g_mse))
print("R2 Score: {:.4f}".format(r2_score(y_test, model_g.predict(X_test_ad))))
# Out:
# Training Set MAE:23.723022
# MSE:1939.759511
# RMSE Score:  44.04270099122785
# R2 Score: 0.5927

# %%
#model_g = ensemble.GradientBoostingRegressor()

#this parameter is just to explore which one would generate the best results
#Once the results are generated by fitting the model,
#The best parameter tells us how we should adjust our numbers in the dictionary
param_grid = {
    'n_estimators':[500,600],
    'learning_rate':[0.02, 0.05],
    'max_depth':[9,10,11],
    'min_samples_leaf':[8,9,10],
    'max_features':[0.3,0.35,0.4],
    'loss':['huber']
}

gb_grid = GridSearchCV(model_g, param_grid, n_jobs =4)

gb_grid.fit(X_train_ad, y_train)

print("The best hyper parameter setting is {}".format(gb_grid.best_params_))

# %%
#check the model's score, also the accuracy
print(model_g.score(X_test_ad, y_test))

# %%
#Name the importance of the features
#then sort the importance
importances = model_g.feature_importances_ 
indices = np.argsort(importances)[::-1] 
print("Top 10 Important Features\n" )
#for each feature importance in the top 15 of them,
for f in range(15): 
    #print out each of the feature's importance
    print("%d. %s (%f)" % (f + 1, X.columns[indices[f]], importances[indices[f]])) 
    #Plot the feature importances of the forest 
    indices=indices[:15] 
#plot a figure that has all of the 15 features using barplot
#rotate the xticks for readability
plt.figure()
plt.title("Top 15 Feature importances") 
plt.bar(range(15), importances[indices], color="orange", align="center") 
plt.xticks(range(15), X.columns[indices], fontsize=10, rotation=90) 
plt.xlim([-1, 15]) 
plt.show() 
#Mean Feature Importance 
print("Mean Feature Importance %.2f"% np.mean(importances))

# %% [markdown]
# # XGBoost
# I did not use xgboost but still kept it for reference because I think it is a great model with more computing power. It just takes too long to run on a personal computer, with such a large dataset, and multiple parameters to consider.
#
# I did not run the part of the code that fine tuness the xgboost regressor because it would take too long to generate results.

# %%
#Here I am putting the y_test value and the model's prediction of the test set into arrays
#Then I will later use them to calculate the RMSE score
y_true = np.array(y_test)
y_pred = np.array(model.predict(dtest))

# %%
#Here I am checking what the R2 score
#The R2 score is the 1-(sum of square of residuals (errors)/sum of square of total) 
print("R2 Score: {:.4f}".format(r2_score(y_true, y_pred)))

# %%
#Print the measuring metrics for this model
print("XGBoost RMSE score on training set: ", np.sqrt(mean_squared_error(y_test, y_pred)))
print("XGBoost MSE score on test set: ", mean_squared_error(y_test, y_pred))

# %%
#inspect the test data
df_test3.head()

# %%
from sklearn.model_selection import cross_val_score
lm_xgb = xgb.XGBRegressor()

print(cross_val_score(lm_xgb, np.array(X), np.array(y), # estimator, features, target
                cv=5, # number of folds 
                scoring='r2'))

print(np.mean(cross_val_score(lm_xgb, X, y, cv=5, scoring='r2')))

# %%
import xgboost as xgb
from xgboost import plot_importance
from sklearn.metrics import  mean_squared_error, r2_score

param_x = {
    'learning_rate':0.2,
    'max_depth':4
}
# Running model a XGB Regressor
model_x = xgb.XGBRegressor()

# Fit the model on training data
model_x.fit(X_train, y_train)

# Predict
pred_train = model_x.predict(X_train)

# Validate
pred_val = model_x.predict(X_test)

print("\nTraining MSE:", round(mean_squared_error(y_train, pred_train),4))
print("Validation MSE:", round(mean_squared_error(y_test, pred_val),4))
print("\nTraining r2:", round(r2_score(y_train, pred_train),4))
print("Validation r2:", round(r2_score(y_test, pred_val),4))

# %%
#translate the dataframe into xgboost format
dtest_actual = xgb.DMatrix(data =df_test3)

# %%
#make predictions using the xgboost model
sal_pred = np.round(model_g.predict(df_test3))
sal_int =sal_pred.astype(int)

# %%
#save the results in a datafram
salary = pd.DataFrame(sal_int)

# %%
#check the dataframe
salary.head()

# %%
#rename the column
salary2 = salary.rename({0: 'salary'}, axis=1)

# %%
#merge the dataframs together
df_test_out = pd.merge(df_test2, salary2, how = 'left',left_index = True, right_index = True)

# %%
#make a dataframe with the desired columns
test_salaries = df_test_out[['jobId','salary']]

# %%
test_salaries.describe()

# %%
#save as csv file
test_salaries.to_csv('test_salaries.csv')

# %%
#here are the parameters with the values
new_params = {'n_estimators':[50,100],
              'learning_rate':[0.2,0.15],
              'max_depth':[2,3],
#              'colsample_bytree':[0.4,0.6,0.8],
#              'gamma':[0,0.03,0.1,0.3],
#              'min_child_weight':[1.5,6,10],
              'random_state':[0]
}

#The logic is similar to gradient boosting. Finding the best outcome here. 
xgb_model = xgb.XGBRegressor()


xgb_grid = GridSearchCV(estimator = xgb_model, 
                        param_grid = new_params, 
                        n_jobs=5, #max number of concurrent workers
                        verbose=False, #work quietly
                        scoring='neg_mean_squared_error')

# %%
#fit the model if time allows. This will take a long time. 
xgb_grid.fit(X_train, y_train)

# %%
#Get the best paramester based on the fitted model. 
print("The best hyper parameter setting is {}".format(xgb_grid.best_params_))

# %%
#build the final model with parameters specified in the last best params
final_xgb_model = xgb.XGBRegressor(n_estimators=100,
                                   learning_rate=0.2,
                                   max_depth=3,
                                   random_state = 0)

# %%
final_xgb_model.fit(X_train, y_train)

# %% [markdown]
# # Extra XGBoost Section That Did Not Use
# I commented them out to avoid confusion.

# %%
# model.score(X2_test, y2_test)

# %%
# xgb_grid.fit(X_train, y_train)

# # summarize the results of the grid search
# #print("The best score is {}".format(xgb_grid.best_score_))
# print("The best hyper parameter setting is {}".format(xgb_grid.best_params_))

# %%
# pred = xgb_grid.predict(X_test)
#test_z_prob = xgb_grid.predict_proba(X_test)[:,1]

#print("model accuracy: {}".format(accuracy_score(y_test, test_z)))
#print("model ROC AUC: {}".format(roc_auc_score(y_test, test_z_prob)))

# %%
# model.score(X_test, y_test)
